# %%
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifie

# %%
df = pd.read_csv('./dataframe.csv')

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df.describe()
# Out:
#               score  error_position
# count  45355.000000    45355.000000
# mean      26.374181       32.752949
# std        5.518838       33.898574
# min        0.000000        0.000000
# 25%       23.000000       10.000000
# 50%       26.000000       22.000000
# 75%       30.000000       43.000000
# max       40.000000      341.000000

# %%
list(df)
# Out:
# ['head',
#  'language',
#  'score',
#  'exam_score',
#  'line',
#  'error_position',
#  'error_type',
#  'correct_sentence',
#  'error_trigram',
#  'correct_trigram',
#  'error_bigram',
#  'correct_bigram',
#  'error_pos',
#  'correct_pos']

# %%
def concat_dummies(df, dummies):
    for dummy in list(dummies):
        df[dummy] = dummies[dummy]

# %%
error_types = pd.get_dummies(df['error_type'], prefix='type')

# %%
concat_dummies(df, error_types)
df.describe()
# Out:
#               score  error_position       type_AG      type_AGA      type_AGD  \
# count  45355.000000    45355.000000  45355.000000  45355.000000  45355.000000
# mean      26.374181       32.752949      0.000088      0.004189      0.002425
# std        5.518838       33.898574      0.009391      0.064589      0.049188
# min        0.000000        0.000000      0.000000      0.000000      0.000000
# 25%       23.000000       10.000000      0.000000      0.000000      0.000000
# 50%       26.000000       22.000000      0.000000      0.000000      0.000000
# 75%       30.000000       43.000000      0.000000      0.000000      0.000000
# max       40.000000      341.000000      1.000000      1.000000      1.000000
#
#            type_AGN      type_AGQ      type_AGV       type_AS       type_CD  \
# count  45355.000000  45355.000000  45355.000000  45355.000000  45355.000000
# mean       0.016867      0.001014      0.018300      0.004564      0.000132
# ...

# %%
error_types_agg = {'error_type': 'count', 'language': 'first'}
for error_type in list(error_types):
    error_types_agg[error_type] = sum

learners = df.groupby('head').agg(error_types_agg)
learners[list(error_types)] = learners[list(error_types)].div(learners[list(error_types)].sum(axis=1), axis=0)

# %%
learners
# Out:
#                     error_type    language  type_AG  type_AGA  type_AGD  \
# head
# OU1*0102*2001*03            29      Polish      0.0  0.000000  0.000000
# OU2*0102*2001*02            10      Polish      0.0  0.000000  0.000000
# OU3*0102*2001*02            19     Russian      0.0  0.052632  0.000000
# OU4*0102*2001*03            15     Turkish      0.0  0.000000  0.000000
# OU5*0102*2001*01            15    Japanese      0.0  0.066667  0.000000
# OU6*0101*2001*01            39       Greek      0.0  0.000000  0.000000
# TE1*0100*2001*01            15      French      0.0  0.000000  0.000000
# TE10*0100*2001*01           23     Chinese      0.0  0.000000  0.000000
# TE11*0100*2001*01           37     Italian      0.0  0.000000  0.000000
# TE12*0100*2001*01           27    Japanese      0.0  0.000000  0.000000
# TE13*0100*2001*01           37     Italian      0.0  0.000000  0.000000
# TE14*0100*2001*01           36     Russian      0.0  0.000000  0.000000
# ...

# %%
columns = list(learners)
columns.remove(('language'))
y = learners['language']

x_train, x_test, y_train, y_test = train_test_split(learners[columns], y, test_size=0.1)

# %%
neigh = KNeighborsClassifier(n_neighbors=10)
neigh.fit(x_train, y_train)
neigh.score(x_test, y_test)
# Out:
# 0.128
